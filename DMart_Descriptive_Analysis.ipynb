# %% [markdown]
# # Descriptive Statistical Analysis of DMart Sales Data

# %% [markdown]
# **Date:** 2025-04-30
#
# **Objective:** Explore and analyze the DMart sales dataset using descriptive statistics and visualization techniques.

# %% [markdown]
# ## Task 1: Load and Preview the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../dmart.csv")
df.head()
# Out:
#   Customer ID Product ID   Order ID  Customer Age  Gender  \
# 0       YSB75      BW653  479577309            28  Female
# 1       FUS93      XV061  634865221            47    Male
# 2       AJP28      GF695  113166210            63  Female
# 3       URC55      VM478  740539230            41    Male
# 4       ZOP23      XD230  156544145            22  Female
#
#                             Product Name      MRP  Discount Price  Category  \
# 0  Ariel Matic Top Load Liquid Detergent   977.44          909.02  Imported
# 1                         VSR Channa Dal   834.09          450.41   Branded
# 2          Tenali Double Horse Chana Dal  1095.20         1007.58   Branded
# 3                               Tata Tea   748.16          389.04  Imported
# 4                         VSR Channa Dal  1249.04          911.80     Local
#
#             State  ... Delivery Date Cancellation Date  Payment Method  \
# 0  Andhra Pradesh  ...    13-05-2022               NaN          Credit
# 1       Telangana  ...    20-08-2021               NaN           Debit
# 2         Gujarat  ...    26-10-2021               NaN           Debit
# 3     Maharashtra  ...    27-08-2021               NaN          Credit
# 4         Gujarat  ...    10-12-2023               NaN          Credit
#
#    Pin Code  Total Order Value Payment Status No of Clicks  Year     Month  \
# 0    318324             909.02           Paid           29  2022       May
# 1    730162             450.41           Paid           95  2021    August
# 2    694091            1007.58           Paid           51  2021   October
# 3    211807             489.04        Pending           12  2021    August
# 4     78304             1011.8           Paid           26  2023  December
#
#   Shipping Charges
# 0                0
# 1                0
# 2                0
# 3              100
# 4              100
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer ID              25000 non-null  object
#  1   Product ID               25000 non-null  object
#  2   Order ID                 25000 non-null  int64
#  3   Customer Age             25000 non-null  int64
#  4   Gender                   25000 non-null  object
#  5   Product Name             25000 non-null  object
#  6   MRP                      25000 non-null  float64
#  7   Discount Price           25000 non-null  float64
#  8   Category                 25000 non-null  object
#  9   State                    25000 non-null  object
#  10  City                     25000 non-null  object
#  11  Subscription             25000 non-null  object
#  12  Bill Number              25000 non-null  float64
#  13  Time Spent on Website    25000 non-null  float64
#  14  Rating                   25000 non-null  float64
#  15  Marketing/Advertisement  25000 non-null  object
#  16  Ship Mode                25000 non-null  object
#  17  Order Status             25000 non-null  object
#  18  Order Date               25000 non-null  object
#  19  Delivery Date            25000 non-null  object
#  20  Cancellation Date        1784 non-null   object
#  21  Payment Method           25000 non-null  object
#  22  Pin Code                 25000 non-null  int64
#  23  Total Order Value        25000 non-null  object
#  24  Payment Status           25000 non-null  object
#  25  No of Clicks             25000 non-null  int64
#  26  Year                     25000 non-null  int64
#  27  Month                    25000 non-null  object
#  28  Shipping Charges         25000 non-null  object
# dtypes: float64(5), int64(5), object(19)
# memory usage: 5.5+ MB

# %%
np.round(df.describe())
# Out:
#           Order ID  Customer Age      MRP  Discount Price   Bill Number  \
# count      25000.0       25000.0  25000.0         25000.0  2.500000e+04
# mean   498712983.0          44.0   1014.0           736.0  5.016695e+11
# std    288189483.0          15.0    571.0           441.0  2.887202e+11
# min        19128.0          18.0     20.0            11.0  2.349474e+07
# 25%    250374576.0          31.0    524.0           368.0  2.540000e+11
# 50%    499731127.0          44.0   1014.0           713.0  5.020000e+11
# 75%    747102105.0          57.0   1507.0          1061.0  7.520000e+11
# max    999913093.0          70.0   2000.0          1876.0  1.000000e+12
#
#        Time Spent on Website   Rating  Pin Code  No of Clicks     Year
# count                25000.0  25000.0   25000.0       25000.0  25000.0
# mean                    10.0      3.0  496731.0          50.0   2022.0
# std                     11.0      1.0  287727.0          29.0      1.0
# min                      1.0      1.0       5.0           1.0   2021.0
# 25%                      3.0      2.0  247984.0          26.0   2021.0
# 50%                      5.0      3.0  495216.0          50.0   2022.0
# 75%                     13.0      4.0  745846.0          76.0   2023.0
# max                     60.0      5.0  999997.0         100.0   2023.0

# %% [markdown]
# ## Task 2: Data Cleaning

# %% [markdown]
# ## Task 3: Descriptive Statistics

# %%
import Stats
Stats.cal_stats("************* Analysis of Discount Price **********************", df['Discount Price'])
# Out:
# ************* Analysis of Discount Price **********************
# Total Sum 18390537.72
# Total Count 25000
# Minimum 10.91
# Maximum 1876.22
# Range 1865.31
# Average 735.62
# Median 713.14
# Mode ModeResult(mode=906.81, count=4)
# Q1 367.665
# Q3 1061.3474999999999
# IQR 693.6824999999999
# Lower Whisker -672.8587499999999
# Upper Whisker 2101.8712499999997
# Variance 194793.34374779632
# Standard Deviation 441.35398916039753
# Skewness 0.27305053943372465
# Kurtosis -0.8095700707373208

# %% [markdown]
# ## Task 4: Visualizations

# %%
sns.displot(df['Discount Price'], kde=True)
plt.show()

# %%
# customers are visting store on end-of-month

df['Delivery Date'] = pd.to_datetime(df['Delivery Date'])
sns.displot(df['Delivery Date'].dt.day)

# %%
# More no. of Gender male are visiting Store than female

sns.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
# Local categories are majorly sold

sns.countplot(df['Category'])
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
# pie chart - State wise Orders

state_counts = df['State'].value_counts()
plt.pie(x=state_counts.values, labels=state_counts.index, autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1fe83bb2930>,
#   <matplotlib.patches.Wedge at 0x1fe83b3a780>,
#   <matplotlib.patches.Wedge at 0x1fe885356a0>,
#   <matplotlib.patches.Wedge at 0x1fe88535d30>],
#  [Text(0.7686744472456659, 0.7868542394570739, 'Maharashtra'),
#   Text(-0.7977848790877426, 0.757323766099385, 'Andhra Pradesh'),
#   Text(-0.7558186070124202, -0.7992110067396501, 'Gujarat'),
#   Text(0.7883017824076374, -0.7671898721000834, 'Telangana')],
#  [Text(0.41927697122490865, 0.42919322152204026, '25.4%'),
#   Text(-0.4351553885933141, 0.4130856905996645, '25.1%'),
#   Text(-0.4122646947340473, -0.4359332764034454, '25.0%'),
#   Text(0.4299827904041658, -0.4184672029636818, '24.6%')])

# %% [markdown]
# ## Task 5: Grouped Analysis

# %%
# What is the distribution of customers by age and gender? Are certain age groups more active in purchasing?

sns.displot(df, x='Customer Age', hue='Gender', kind='kde')
plt.title("Customer Age Distribution by Gender")
plt.show()

# %%
# How does customer subscription status affect total purchase value?

subscription_data = df.groupby('Subscription')['Total Order Value'].sum()
df['Total Order Value'] = pd.to_numeric(df['Total Order Value'], errors='coerce')
plt.figure(figsize=(20,5)) 
sns.barplot(hue=subscription_data.index, y=subscription_data.values, palette="viridis", legend=True)
plt.xlabel("Subscription Type")
plt.ylabel("Total Order Value")
plt.title("Total Order Value by Subscription Type")
plt.show()

# %%
# How does customer subscription status affect total purchase value by Category?

sub_category = df.groupby('Subscription')['Category'].value_counts().reset_index(name='Count')
plt.figure(figsize=(20,5)) 

sns.barplot(x='Subscription', y='Count', hue='Category', data=sub_category, palette="viridis")
plt.xlabel("Subscription Type")
plt.ylabel("Total Order Value")
plt.title("Total Order Value by Subscription Type")
# Out:
# Text(0.5, 1.0, 'Total Order Value by Subscription Type')

# %%
# What are the top-selling products based on total order value?

df.groupby('Product Name')['Total Order Value'].sum()

# Harpic Bathroom Cleaner - Floral is selling at top with revenue of 828936.33 highest among all products
# Out:
# Product Name
# Amul Butter Unsalted                          716160.11
# Amul Taaza Toned Milk                         747005.04
# Ariel Matic Front Load Liquid Detergent       772729.63
# Ariel Matic Top Load Liquid Detergent         759997.11
# Cavin's Chocolate Milkshake                   783507.63
# Harpic Bathroom Cleaner - Floral              828936.33
# Kellogg's Corn Flakes                         749989.92
# Nimyle Herbal Anti-Bacterial Floor Cleaner    807119.09
# Nutri Delite Breakfast Cereal                 795287.72
# Parle Nutricrunch Digestive Cookies           821713.48
# Pigeon Induction Cooktop Acer Plus: 1800 W    753636.44
# Premia Tur Dal Latur (Kandi Pappu)            736505.19
# Sofit Soya Drink Vanilla                      744676.91
# Sunfeast Dark Fantasy Yumfills Cake           733203.70
# Tata Sampann Chana Dal                        736310.70
# Tata Sampann Moong Dal (Pesara Pappu)         804085.34
# Tata Tea                                      775769.57
# Tata Tea Chakra Gold Premium Tea              796072.08
# Tenali Double Horse Chana Dal                 783678.89
# Usha Heavy Weight Iron - El3710: 1000 W       775167.13
# VSR Channa Dal                                712389.62
# Wagh Bakri Masala Tea                         820167.70
# Name: Total Order Value, dtype: float64

# %%
# What are the top-selling categories based on total order value?

df.groupby('Category')['Total Order Value'].su()
# Out:
# Category
# Branded     5124795.11
# Imported    3347278.74
# Local       8482035.48
# Name: Total Order Value, dtype: float64

# %%
# What cities and states have the highest number of orders?
state_city = df.groupby('State')['City'].value_counts()
state_city

# Gujrat's Vadodara has highest number of orders
# Maharashtra's Navi-Mumbai has highest number of orders
# Andra's Guntur has highest number of orders
# Telanganas's Suryapet has highest number of orders
# at the end Maharshtra state has highest number of orders
# Out:
# State           City
# Andhra Pradesh  Guntur           678
#                 Visakhapatnam    657
#                 Rajahmundry      648
#                 Vizianagaram     631
#                 Anantapur        630
#                 Tirupati         627
#                 Kurnool          616
#                 Vijayawada       607
#                 Kadapa           592
#                 Nellore          585
# Gujarat         Vadodara         679
#                 Bharuch          648
#                 Surat            637
#                 Ahmedabad        625
#                 Junagadh         624
#                 Bhavnagar        616
#                 Jamnagar         615
#                 Gandhinagar      608
#                 Anand            606
#                 Rajkot           586
# Maharashtra     Navi Mumbai      678
#                 Thane            645
#                 Aurangabad       643
#                 Nagpur           643
#                 Kolhapur         634
#                 Amravati         633
#                 Nashik           633
#                 Solapur          619
#                 Mumbai           612
#                 Pune             603
# Telangana       Suryapet         669
#                 Nizamabad        640
#                 Warangal         637
#                 Karimnagar       614
#                 Ramagundam       607
#                 Khammam          604
#                 Hyderabad        603
#                 Mahbubnagar      598
#                 Nalgonda         590
#                 Adilabad         580
# Name: count, dtype: int64

# %%
# Orders that are cancelled

df[df['Cancellation Date'].notnull()].head()
# Out:
#    Customer ID Product ID   Order ID  Customer Age  Gender  \
# 11       EBX76      CK701  802397574            22  Female
# 39       PGN88      OU881  459363743            26  Female
# 63       UOA47      TI314  496703808            53  Female
# 74       EQQ34      BD183  377116785            70  Female
# 98       GYF09      GP840  940317891            57    Male
#
#                                   Product Name      MRP  Discount Price  \
# 11                              VSR Channa Dal   628.34          534.09
# 39               Nutri Delite Breakfast Cereal  1311.33         1062.18
# 63  Pigeon Induction Cooktop Acer Plus: 1800 W  1128.90          598.32
# 74                      Tata Sampann Chana Dal   309.88          204.52
# 98     Usha Heavy Weight Iron - El3710: 1000 W  1450.55         1073.41
#
#     Category           State  ... Delivery Date Cancellation Date  \
# 11   Branded       Telangana  ...    11-01-2021        21-01-2021
# 39     Local       Telangana  ...    30-08-2023        09-09-2023
# 63     Local  Andhra Pradesh  ...    17-01-2023        28-01-2023
# 74     Local  Andhra Pradesh  ...    02-02-2023        11-02-2023
# 98  Imported     Maharashtra  ...    02-10-2021        10-10-2021
#
#     Payment Method  Pin Code  Total Order Value Payment Status No of Clicks  \
# 11       Cancelled    142985          Cancelled      Cancelled           82
# 39       Cancelled    242842          Cancelled      Cancelled            7
# 63       Cancelled     13033          Cancelled      Cancelled           23
# 74       Cancelled    225011          Cancelled      Cancelled           48
# 98       Cancelled    582172          Cancelled      Cancelled           41
#
#     Year      Month Shipping Charges
# 11  2021    January        Cancelled
# 39  2023     August        Cancelled
# 63  2023    January        Cancelled
# 74  2023    January        Cancelled
# 98  2021  September        Cancelled
#
# [5 rows x 29 columns]

# %%
# Which months show peak sales trends?

(df['Month'].value_counts())
# Out:
# Month
# August       2182
# December     2155
# November     2149
# October      2141
# March        2132
# May          2120
# July         2120
# April        2066
# June         2012
# January      2003
# September    1962
# February     1958
# Name: count, dtype: int64

# %%
# Products per category

df.groupby('Category')['Product Name'].count()

# %%
# What is top-selling category per State

df.groupby('State')['Category'].value_counts()
# Out:
# State           Category
# Andhra Pradesh  Local       3095
#                 Branded     1889
#                 Imported    1287
# Gujarat         Local       3135
#                 Branded     1868
#                 Imported    1241
# Maharashtra     Local       3131
#                 Branded     1934
#                 Imported    1278
# Telangana       Local       3041
#                 Branded     1873
#                 Imported    1228
# Name: count, dtype: int64

# %%
clicks = df[df['Payment Status'] == 'Cancelled'].groupby('Payment Status')['No of Clicks'].unique()
clicks
# Out:
# Payment Status
# Cancelled    [82, 7, 23, 48, 41, 80, 66, 63, 70, 3, 31, 93,...
# Name: No of Clicks, dtype: object

# %% [markdown]
# ## Task 6: Correlation Heatmap

# %%
df.corr(numeric_only=True)
# Out:
#                        Order ID  Customer Age       MRP  Discount Price  \
# Order ID               1.000000      0.004029 -0.012578       -0.014953
# Customer Age           0.004029      1.000000 -0.002645       -0.001191
# MRP                   -0.012578     -0.002645  1.000000        0.938884
# Discount Price        -0.014953     -0.001191  0.938884        1.000000
# Bill Number           -0.006906      0.006837  0.002730        0.001909
# Time Spent on Website -0.001416      0.005204 -0.004074       -0.006862
# Rating                -0.004566      0.001667  0.011017        0.010278
# Pin Code               0.002319      0.005226  0.001353       -0.001688
# No of Clicks           0.003566     -0.000120  0.000271        0.000560
# Year                  -0.005185      0.013787  0.013178        0.010862
#
#                        Bill Number  Time Spent on Website    Rating  Pin Code  \
# Order ID                 -0.006906              -0.001416 -0.004566  0.002319
# Customer Age              0.006837               0.005204  0.001667  0.005226
# MRP                       0.002730              -0.004074  0.011017  0.001353
# Discount Price            0.001909              -0.006862  0.010278 -0.001688
# Bill Number               1.000000               0.004024 -0.002965 -0.001340
# Time Spent on Website     0.004024               1.000000 -0.002675 -0.007556
# Rating                   -0.002965              -0.002675  1.000000 -0.001555
# Pin Code                 -0.001340              -0.007556 -0.001555  1.000000
# No of Clicks              0.007198               0.004644 -0.009305  0.006233
# Year                      0.013344               0.003976  0.009763 -0.013599
#
#                        No of Clicks      Year
# Order ID                   0.003566 -0.005185
# Customer Age              -0.000120  0.013787
# MRP                        0.000271  0.013178
# Discount Price             0.000560  0.010862
# Bill Number                0.007198  0.013344
# Time Spent on Website      0.004644  0.003976
# Rating                    -0.009305  0.009763
# Pin Code                   0.006233 -0.013599
# No of Clicks               1.000000 -0.005224
# Year                      -0.005224  1.000000

# %%
corr_matrix = df[['MRP', 'Discount Price', 'Customer Age', 'Total Order Value']].corr()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, vmax=1, vmin=-1, cmap='viridis', linewidths=0.5, fmt=".2f")

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Task 7: Observations

# %% [markdown]
# Write 3-5 key insights you observed from your descriptive analysis.

# %%
# Sales in Maharashtra are more than other states
# customers are visting store on end-of-month
# Males are visiting Store than female
# Local categories are majorly sold
# Age 32 is more active in purchasing
# Customers having freepass are only resturning or cancelling orders
# There no correlation between Discount and age
# Product "Harpic Bathroom Cleaner - Floral" is selling at top with revenue of 828936.33 highest among all products
